# %% [markdown]
# ### Count of resources per class

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper(
    "https://lod.onb.ac.at/sparql/anno"
)
sparql.setReturnFormat(JSON)

# skos:Concept
# edm:ProvidedCHO
# ore:Aggregation
# sioc:Service
sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select (count(distinct ?s) as ?t) where {
 # ?s a sioc:Service
}limit 10
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'t': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '2482487'}}

# %% [markdown]
# ### Properties for the resource
# http://data.onb.ac.at/ANNO/a441836bl01

# %%
sparql = SPARQLWrapper(
    "https://lod.onb.ac.at/sparql/anno"
)
sparql.setReturnFormat(JSON)

sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select * where {
 <http://data.onb.ac.at/ANNO/a441836bl01> ?p ?o
}
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/spatial'}, 'o': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4066009-6'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/hasView'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/anno_pdf.pl?aid=a44&datum=1836bl01'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/hasView'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/annoshow?call=a44|1836bl01|2|100|0'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/isShownAt'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/anno?aid=a44&datum=1836bl01'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/isShownBy'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/annoshow?call=a44|1836bl01|1|100|0'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/provider'}, 'o': {'type': 'literal', 'value': 'Austrian National Library'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/rights'}, 'o': {'type': 'uri', 'value': 'http://rightsstatements.org/page/NoC-NC/1.0/'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/type'}, 'o': {'type': 'literal', 'value': 'TEXT'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/ProvidedCHO'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://www.openarchives.org/ore/terms/Aggregation'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/title'}, 'o': {'type': 'literal', 'value': 'Der Telegraph'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/title'}, 'o': {'type': 'literal', 'value': 'Inhaltsverzeichnis'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/subject'}, 'o': {'type': 'literal', 'value': 'Kunst; Literatur; Theater; Tageszeitung; Wirtschaft'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/date'}, 'o': {'type': 'literal', 'value': '1836'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/type'}, 'o': {'type': 'literal', 'value': 'newspaper'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/identifier'}, 'o': {'type': 'literal', 'value': 'a441836bl01'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/language'}, 'o': {'type': 'literal', 'value': 'de'}}

# %% [markdown]
# ## Retrieve list of resources to create ShEx schemas

# %%
sparql = SPARQLWrapper(
    "https://lod.onb.ac.at/sparql/anno"
)
sparql.setReturnFormat(JSON)

# skos:Concept
# edm:ProvidedCHO
# ore:Aggregation
# sioc:Service
# filter(!regex(str(?s), "file")) . filter(!regex(str(?s), "gnd"))
sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select distinct ?s 
 where {
     # ?s a skos:Concept . ?s skos:prefLabel ?l . filter(!regex(str(?s), "file"))
 }limit 200
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4066009-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4062901-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4067510-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4012995-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4018202-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4039305-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4074255-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4002851-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4033114-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4074335-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4103444-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4021912-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4259231-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4017013-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4031955-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4218775-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4011077-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4049396-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4034402-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/25664-X'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4046514-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4030921-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4040802-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4035206-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4048737-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4062501-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4038243-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/10159443-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4058282-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4056366-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4041358-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4125698-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4076741-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4153309-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4004168-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4023299-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4112560-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4039792-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4066562-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4127793-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4007202-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4076310-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4008306-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4142298-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4114333-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4066399-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4027096-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4059205-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4008456-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4076982-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4006650-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4035964-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4005728-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4037100-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4051752-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4061190-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4802178-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4049275-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4008099-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4014087-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4007901-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4020517-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/501527-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4089103-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4020754-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4073953-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4086227-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4063533-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4027718-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4125302-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4008460-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4012792-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/1028233-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4028808-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4272197-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4119250-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4075643-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4045895-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4072443-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4026170-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4033488-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4076145-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4078411-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4051622-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4088293-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4090940-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4016680-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4098732-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4029705-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4018636-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4096933-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4103609-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4075404-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4078405-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4021477-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/1027741-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4108909-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4021652-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4111437-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4071971-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4008213-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4104043-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4037124-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4012804-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4116052-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4029713-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4096494-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4073760-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/5265796-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4114978-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4074136-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4107955-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4066023-0'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4028859-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4114985-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4033043-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4073842-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4127843-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4520653-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4039880-8'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4508889-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4220547-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4031235-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4380628-4'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4312296-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4008037-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4057648-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4061019-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4075578-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4051891-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4044970-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4103049-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4108646-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4013176-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4048230-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4003614-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4021376-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4057496-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/5111296-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4106190-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4059481-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/402092-3'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4405250-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4115170-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4092326-5'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4047704-6'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4059702-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4041812-1'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4067185-9'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4305227-7'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4023349-2'}}
# {'s': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4031483-2'}}

# %% [markdown]
# ### Incorrect URIs file:/data/anno/aua18580603.rdf 35733

# %%
sparql = SPARQLWrapper(
    "https://lod.onb.ac.at/sparql/anno"
)
sparql.setReturnFormat(JSON)

# skos:Concept
# edm:ProvidedCHO
# ore:Aggregation
# sioc:Service
# filter(!regex(str(?s), "file")) . filter(!regex(str(?s), "gnd"))
sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select (count(distinct ?s) as ?t) 
 where {
     # ?s a skos:Concept . filter(regex(str(?s), "file"))
 }
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
    

sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select distinct ?s
 where {
     # ?s a skos:Concept . filter(regex(str(?s), "file"))
 }limit 10
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'t': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'type': 'literal', 'value': '35733'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580603.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580606.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580610.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580613.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580617.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580620.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580624.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580627.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580704.rdf'}}
# {'s': {'type': 'uri', 'value': 'file:/data/anno/aua18580708.rdf'}}

# %%
sparql = SPARQLWrapper(
    "https://lod.onb.ac.at/sparql/anno"
)
sparql.setReturnFormat(JSON)

# skos:Concept
# edm:ProvidedCHO
# ore:Aggregation
# sioc:Service
# filter(!regex(str(?s), "file")) . filter(!regex(str(?s), "gnd"))
sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select distinct ?s 
 where {
     # ?s a edm:ProvidedCHO . 
 }limit 200
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360819'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360822'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360824'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360826'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360829'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360831'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360902'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360905'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360907'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360909'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360912'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360914'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360916'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360919'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360921'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360923'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360926'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360928'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360930'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361003'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361005'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361007'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361010'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361012'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361014'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361017'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361019'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361021'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361024'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361026'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361028'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361031'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361102'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361104'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361107'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361109'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361111'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361114'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361116'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361118'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361121'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361123'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361125'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361128'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361130'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361202'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361205'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361207'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361209'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361212'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361214'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361216'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361219'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361221'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361223'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361227'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361228'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418361230'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a441836bl01'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a441836bl02'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370102'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370104'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370107'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370109'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370111'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370113'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370116'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370118'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370120'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370123'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370125'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370127'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370130'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370201'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370203'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370206'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370208'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370210'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370213'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370215'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370217'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370220'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370222'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370224'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370227'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370301'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370303'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370306'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370308'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370310'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370313'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370315'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370317'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370320'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370322'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370324'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370325'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370329'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370331'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418370404'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360118'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360120'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360122'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360125'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360127'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360129'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360201'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360203'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360205'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360208'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360210'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360212'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360215'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360217'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360219'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360220'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360222'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360224'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360226'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360227'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360229'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360302'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360304'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360305'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360307'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360309'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360311'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360312'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360314'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360316'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360318'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360319'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360321'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360323'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360324'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360326'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360328'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360330'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360331'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360401'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360404'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360406'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360408'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360411'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360413'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360415'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360418'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360420'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360422'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360425'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360427'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360429'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360430'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360502'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360504'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360506'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360509'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360511'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360513'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360516'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360518'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360520'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360523'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360525'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360527'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360530'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360601'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360603'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360606'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360608'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360610'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360613'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360615'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360617'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360620'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360622'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360624'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360627'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360629'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360701'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360704'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360706'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360708'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360711'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360713'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360715'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360718'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360720'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360722'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360725'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360727'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360729'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360801'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360803'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360805'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360808'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360810'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360812'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360815'}}
# {'s': {'type': 'uri', 'value': 'http://data.onb.ac.at/ANNO/a4418360817'}}

# %%
sparql = SPARQLWrapper(
    "https://lod.onb.ac.at/sparql/anno"
)
sparql.setReturnFormat(JSON)

sparql.setQuery("""
    PREFIX ore: <http://www.openarchives.org/ore/terms/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX edm: <http://www.europeana.eu/schemas/edm/>
    PREFIX sioc: <http://rdfs.org/sioc/services#>
 select * where {
 <http://data.onb.ac.at/ANNO/a4418370412> ?p ?o
}
    """
)

try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print(r)
except Exception as e:
    print(e)
# Out:
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/spatial'}, 'o': {'type': 'uri', 'value': 'http://d-nb.info/gnd/4066009-6'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/hasView'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/anno_pdf.pl?aid=a44&datum=18370412'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/hasView'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/annoshow?call=a44|18370412|2|100|0'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/hasView'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/annoshow?call=a44|18370412|3|100|0'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/hasView'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/annoshow?call=a44|18370412|4|100|0'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/isShownAt'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/anno?aid=a44&datum=18370412'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/isShownBy'}, 'o': {'type': 'uri', 'value': 'http://anno.onb.ac.at/cgi-content/annoshow?call=a44|18370412|1|100|0'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/provider'}, 'o': {'type': 'literal', 'value': 'Austrian National Library'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/rights'}, 'o': {'type': 'uri', 'value': 'http://rightsstatements.org/page/NoC-NC/1.0/'}}
# {'p': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/type'}, 'o': {'type': 'literal', 'value': 'TEXT'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://www.europeana.eu/schemas/edm/ProvidedCHO'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://www.openarchives.org/ore/terms/Aggregation'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/title'}, 'o': {'type': 'literal', 'value': 'Der Telegraph'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/subject'}, 'o': {'type': 'literal', 'value': 'Kunst; Literatur; Theater; Tageszeitung; Wirtschaft'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/date'}, 'o': {'type': 'literal', 'value': '1837-04-12'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/type'}, 'o': {'type': 'literal', 'value': 'newspaper'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/identifier'}, 'o': {'type': 'literal', 'value': 'a4418370412'}}
# {'p': {'type': 'uri', 'value': 'http://purl.org/dc/elements/1.1/language'}, 'o': {'type': 'literal', 'value': 'de'}}

# %%
### Incorrect URIS in the repository

# %%
from rdflib import Graph, URIRef, Literal, BNode
from rdflib.namespace import FOAF, RDF

g = Graph()
g.bind("foaf", FOAF)

# Add demo data
bob = URIRef("http://anno.onb.ac.at/cgi-content/annoshow?call=a44|18370412|2|100|0")
# Out:
# http://anno.onb.ac.at/cgi-content/annoshow?call=a44|18370412|2|100|0 does not look like a valid URI, trying to serialize this will break.
